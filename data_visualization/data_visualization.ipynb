# %%
# Import data analysis libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Import data from csv file
data = pd.read_csv('tarifas.csv')

# %%
# Display the rows of the data
data.head(20)
# Out:
#     Empresa                Tarifa  \
# 0   Naturgy        Por uso de Luz
# 1   Naturgy             Noche Luz
# 2   Naturgy                 Solar
# 3   Octopus         Octopus Relax
# 4   Octopus             Octopus 3
# 5   Octopus         Octopus Flexi
# 6   Octopus         Octopus Solar
# 7    Repsol  Tarifa Tranquilisima
# 8    Repsol    Tarifa Ahorro Plus
# 9    Repsol  Tarifa 10h descuento
# 10   Repsol    Tarifa Placa Solar
# 11   Xenera          Home contigo
# 12   Xenera               En casa
# 13   Xenera        A vaquiña fija
# 14   Xenera    Home contigo única
#
#                                           Descripción     Punta     Llano  \
# 0   La energía que consumes  siempre al mismo prec...  0.114900  0.114900
# 1   Un precio diferente por cada tramo horario de ...  0.170000  0.116200
# 2                                                   0  0.170000  0.116200
# 3                           Mismo precio las 24 horas  0.115000  0.115000
# ...

# %%
# Display the information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Empresa           15 non-null     object
#  1   Tarifa            15 non-null     object
#  2   Descripción       15 non-null     object
#  3   Punta             15 non-null     float64
#  4   Llano             15 non-null     float64
#  5   Valle             15 non-null     float64
#  6   P1                15 non-null     float64
#  7   P3                15 non-null     float64
#  8   Excedentes        15 non-null     float64
#  9   Coste de gestión  15 non-null     float64
#  10  Bateria           15 non-null     float64
# dtypes: float64(8), object(3)
# memory usage: 1.4+ KB

# %%
# Visualize the Punta by company in horizontal bar plot
sns.set_style(style='darkgrid')
plt.figure(figsize=(10, 6))
sns.barplot(x='Punta', y='Empresa', data=data, palette='viridis')
plt.title('Punta by Company')
plt.xlabel('Punta')
plt.ylabel('Company')
plt.show()

# %%
# Visualize the Punta by company in horizontal bar plot
sns.set_style(style='darkgrid')
plt.figure(figsize=(10, 6))
sns.barplot(x='Punta', y='Tarifa', data=data, palette='viridis')
plt.title('Punta by Tarifa')
plt.xlabel('Punta')
plt.ylabel('Company')
plt.show()

# %%
# Visualize the llano by company in horizontal bar plot
sns.set_style(style='darkgrid')
plt.figure(figsize=(10, 6))
sns.barplot(x='Llano', y='Empresa', data=data, palette='viridis')
plt.title('Llano by Company')
plt.xlabel('Llano')
plt.ylabel('Company')
plt.show()

# %%
# Visualize the llano by company in horizontal bar plot
sns.set_style(style='darkgrid')
plt.figure(figsize=(10, 6))
sns.barplot(x='Llano', y='Tarifa', data=data, palette='viridis')
plt.title('Llano by Tarifa')
plt.xlabel('Llano')
plt.ylabel('Tarifa')
plt.show()

# %%
# Visualize the Valle by company in horizontal bar plot
sns.set_style(style='darkgrid')
plt.figure(figsize=(10, 6))
sns.barplot(x='Valle', y='Empresa', data=data, palette='viridis')
plt.title('Valle by Company')
plt.xlabel('Valle')
plt.ylabel('Company')
plt.show()

# %%
# Visualize the Valle by Tarifa in horizontal bar plot
sns.set_style(style='darkgrid')
plt.figure(figsize=(10, 6))
sns.barplot(x='Llano', y='Tarifa', data=data, palette='viridis')
plt.title('Valle by Tarifa')
plt.xlabel('Valle')
plt.ylabel('Tarifa')
plt.show()

# %%
# Dashboard with all the plots
sns.set_style(style='darkgrid')

# Crear una figura con un tablero de 3x2
fig, axes = plt.subplots(3, 2, figsize=(15, 15))

# Agregar un título al dashboard
fig.suptitle('Comparativa de Tarifas y Empresas', fontsize=16)

# Gráfico 1: Punta por Empresa
sns.barplot(x='Punta', y='Empresa', data=data, palette='viridis', ax=axes[0, 0])
axes[0, 0].set_title('Punta por Empresa')
axes[0, 0].set_xlabel('Punta')
axes[0, 0].set_ylabel('Empresa')

# Gráfico 2: Punta por Tarifa
sns.barplot(x='Punta', y='Tarifa', data=data, palette='viridis', ax=axes[0, 1])
axes[0, 1].set_title('Punta por Tarifa')
axes[0, 1].set_xlabel('Punta')
axes[0, 1].set_ylabel('Tarifa')

# Gráfico 3: Llano por Empresa
sns.barplot(x='Llano', y='Empresa', data=data, palette='viridis', ax=axes[1, 0])
axes[1, 0].set_title('Llano por Empresa')
axes[1, 0].set_xlabel('Llano')
axes[1, 0].set_ylabel('Empresa')

# Gráfico 4: Llano por Tarifa
sns.barplot(x='Llano', y='Tarifa', data=data, palette='viridis', ax=axes[1, 1])
axes[1, 1].set_title('Llano por Tarifa')
axes[1, 1].set_xlabel('Llano')
axes[1, 1].set_ylabel('Tarifa')

# Gráfico 5: Valle por Empresa
sns.barplot(x='Valle', y='Empresa', data=data, palette='viridis', ax=axes[2, 0])
axes[2, 0].set_title('Valle por Empresa')
axes[2, 0].set_xlabel('Valle')
axes[2, 0].set_ylabel('Empresa')

# Gráfico 6: Valle por Tarifa
sns.barplot(x='Valle', y='Tarifa', data=data, palette='viridis', ax=axes[2, 1])
axes[2, 1].set_title('Valle por Tarifa')
axes[2, 1].set_xlabel('Valle')
axes[2, 1].set_ylabel('Tarifa')

# Ajustar el layout
plt.tight_layout(rect=[0, 0, 1, 0.95]) # Ajustar para dejar espacio para el título
plt.show()

# %%
# Dashboard with P1 and P3 by company
sns.set_style(style='darkgrid')

# Crear una figura con un tablero de 1x2
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Agregar un título al dashboard
fig.suptitle('Comparativa de Potencias por Empresas', fontsize=16)

# Paleta de colores personalizada
palette = sns.color_palette("viridis", as_cmap=True)

# Gráfico 1: Punta 1 por Empresa
sns.barplot(x='P1', y='Empresa', data=data, palette='viridis', ax=axes[0])
axes[0].set_title('P1 por Empresa')
axes[0].set_xlabel('P1')
axes[0].set_ylabel('Empresa')

# Gráfico 2: Punta 3 por Empresa
sns.barplot(x='P3', y='Empresa', data=data, palette='viridis', ax=axes[1])
axes[1].set_title('P3 por Empresa')
axes[1].set_xlabel('P3')
axes[1].set_ylabel('Empresa')

# Ajustar el layout
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Ajustar para dejar espacio para el título
plt.show()

# %%
# Load the data from the csv file
data_solar = pd.read_csv('datos_solares2.csv')

# Display the rows of the data
data_solar.head(10)
# Out:
#      Ciudad  Horas de sol Irradiación
# 0   Almería        3305.0           6
# 1     Cádiz        3316.0           6
# 2   Córdoba        3100.0         5.9
# 3   Granada        3228.0           6
# 4    Huelva        3527.0           6
# 5      Jaén        3289.0         5.8
# 6    Málaga        3248.0         5.8
# 7   Sevilla        3526.0         5.9
# 8    Huesca        3099.0         5.6
# 9  Zaragoza        2620.0         5.6

# %%
# Display the information of the data
data_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ciudad        50 non-null     object
#  1   Horas de sol  50 non-null     float64
#  2   Irradiación   50 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# Filtrar las diez ciudades con más horas de sol
top_cities = data_solar.nlargest(10, 'Horas de sol')

# Visualizar las diez ciudades con más horas de sol
sns.set_style(style='darkgrid')
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Horas de sol', y='Ciudad', data=top_cities, palette='viridis')
plt.title('Top Ten Cities with the Highest Hours of Sun')
plt.xlabel('Hours of Sun')
plt.ylabel('City')

# Añadir etiquetas con los valores dentro de las barras
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f')

plt.show()

# %%
# Filtrar las diez ciudades con menos horas de sol
bottom_cities = data_solar.nsmallest(10, 'Horas de sol')

# Visualizar las diez ciudades con menos horas de sol
sns.set_style(style='darkgrid')
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Horas de sol', y='Ciudad', data=bottom_cities, palette='viridis')
plt.title('Top bottom Cities with the Least Hours of Sun')
plt.xlabel('Hours of Sun')
plt.ylabel('City')

# Añadir etiquetas con los valores dentro de las barras
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f')

plt.show()
